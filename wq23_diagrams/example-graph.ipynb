# %%
import pandas as pd

# %%
d = {"stream-64-stride-1-noverify.riscv": [43.12, 33.1, 12.1, 1.1],
     "stream-64-stride-4-noverify.riscv": [60.12, 32.3, 19.9, 1.2],}
df = pd.DataFrame(d, index=["system1", "system2", "system3", "system4"])
print(df)
# Out:
#          stream-64-stride-1-noverify.riscv  stream-64-stride-4-noverify.riscv
# system1                              43.12                              60.12
# system2                              33.10                              32.30
# system3                              12.10                              19.90
# system4                               1.10                               1.20

# %%
plot = df.plot.bar(figsize=(10, 5), rot=0)
plot.set_xlabel("systems")
plot.set_ylabel("CPI")
plot.set_title("CPI of Different Systems Running Stream Benchmarks of Different Strides")
print()

# %%
plot.get_figure().savefig("CPI-graph-example.svg", format='svg', dpi=1200)
